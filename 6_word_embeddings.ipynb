# %% [markdown]
# # Word Embeddings

# %% [markdown]
# Referencias:
# - http://adventuresinmachinelearning.com/word2vec-tutorial-tensorflow/
# - http://adventuresinmachinelearning.com/word2vec-keras-tutorial/

# %% [markdown]
# Que es?:
# - Mapea "one-hot encoding" de muy alta dimensión en un "word vector" de menor dimensión
# - Termina generando un diccionario de indices a 'word vectors'
# - Cual es la motivación?
#
# Métodos:
# - word2Vec: Utiliza un red neuronal
# - Glove: Matrix factorization
# - Los aprende en función de un contexto específico. (Redes neuronales)

# %% [markdown]
# # Word2Vec

# %% [markdown]
# ![CBOW_SKIP.png](attachment:CBOW_SKIP.png)

# %% [markdown]
# - Continuous Bag Of Words (CBOW): La entrada es el contexto y se predice la palabra
# - Skip-gram model: La entrada es una palabra y se predice el contexto (Probabilidad de que cada palabra este cerca)

# %% [markdown]
# # Skip-gram

# %% [markdown]
# - window: si es 3 significa que toma 2 para arriba y 2 para abajo como parte del contexto

# %% [markdown]
# ## Metodo sofmax

# %% [markdown]
# ![Word2Vec-softmax.jpg](attachment:Word2Vec-softmax.jpg)

# %% [markdown]
# ## Negative Sampling

# %% [markdown]
# ![Negative-sampling.jpg](attachment:Negative-sampling.jpg)
